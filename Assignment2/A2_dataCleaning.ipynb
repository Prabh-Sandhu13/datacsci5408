# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
customers = pd.read_csv("archive/olist_customers_dataset.csv")
customers.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     e17afd09a7415bfaea4762a63683b83e  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers.dropna(axis=0, how='all', thresh=None, subset=None, inplace=True)

# %%
customers.nunique()
# Out:
# customer_id                 99441
# customer_unique_id          96096
# customer_zip_code_prefix    14994
# customer_city                4119
# customer_state                 27
# dtype: int64

# %%
customer_details = customers[['customer_unique_id','customer_zip_code_prefix','customer_city','customer_state']]
customer_details= customer_details.drop_duplicates()

# %%
customer_orderinfo = customers[['customer_id','customer_unique_id']]

# %%
customer_orderinfo = customer_orderinfo.iloc[:200,:]
customer_orderinfo.shape
# Out:
# (200, 2)

# %%
customer_details = customer_details.iloc[:200,:]
customer_details.shape
# Out:
# (200, 4)

# %%
geolocation = pd.read_csv("archive/olist_geolocation_dataset.csv")
geolocation.describe(include='all')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %%
geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geolocation.nunique()
geolocation.shape
# Out:
# (1000163, 5)

# %%
geolocation = geolocation.iloc[:200,:]
geolocation.shape
# Out:
# (200, 5)

# %%
items = pd.read_csv("archive/olist_order_items_dataset.csv")
items.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
items.dropna(axis=0, how='all', thresh=None, subset=None, inplace=True)

# %%
items.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %%
items = items.iloc[:200,:]
items.shape
# Out:
# (200, 7)

# %%
payments = pd.read_csv("archive/olist_order_payments_dataset.csv")
payments.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
payments = payments.iloc[:200,:]
payments.shape
# Out:
# (200, 5)

# %%
reviews = pd.read_csv("archive/olist_order_reviews_dataset.csv")
reviews.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                             100000                            100000
# unique                             99173                             99441
# top     4219a80ab469e3fc9901437b73da3f75  8e17072ec97ce29f0e1f111e598b0c85
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#          review_score review_comment_title review_comment_message  \
# ...

# %%
reviews = reviews.iloc[:200,:]
reviews.shape
# Out:
# (200, 7)

# %%
orders = pd.read_csv("archive/olist_orders_dataset.csv")
orders.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     37e9481cdd40609c76b3f6da7f9af51e  70299e106f6e6cab75bc08777a3a4480
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
orders = orders.iloc[:200,:]
orders.shape
# Out:
# (200, 8)

# %%
products = pd.read_csv("archive/olist_products_dataset.csv")
products.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     b072511d69a5b161d8e80815898ed960       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %%
products = products.iloc[:200,:]
products.shape
# Out:
# (200, 9)

# %%
sellers = pd.read_csv("archive/olist_sellers_dataset.csv")
sellers.describe(include='all')
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     aadfe0417e61315688b6bd7043361e25                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers = sellers.iloc[:200,:]
sellers.shape
# Out:
# (200, 4)

# %%
category = pd.read_csv("archive/product_category_name_translation.csv")
category.describe(include='all')
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top                    audio                          baby
# freq                       1                             1

# %%
category = category.iloc[:200,:]
category.shape
# Out:
# (71, 2)

# %%
customer_details.to_csv("clean_data/customer_details.csv")
customer_orderinfo.to_csv("clean_data/customer_orderinfo.csv")
geolocation.to_csv("clean_data/geolocation.csv")
payments.to_csv("clean_data/payments.csv")
reviews.to_csv("clean_data/reviews.csv")
orders.to_csv("clean_data/orders.csv")
products.to_csv("clean_data/products.csv")
sellers.to_csv("clean_data/sellers.csv")
category.to_csv("clean_data/product_category.csv")

# %%
items.to_csv("clean_data/items.csv")
